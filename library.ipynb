# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# archspec                      0.2.1
# asttokens                     2.4.1
# backports.functools-lru-cache 1.6.5
# blinker                       1.7.0
# boltons                       23.0.0
# Bottleneck                    1.3.5
# Brotli                        1.0.9
# certifi                       2023.7.22
# cffi                          1.15.1
# charset-normalizer            2.0.4
# click                         8.1.7
# colorama                      0.4.6
# comm                          0.1.4
# conda                         23.10.0
# conda-libmamba-solver         23.11.0
# conda-package-handling        2.2.0
# conda_package_streaming       0.9.0
# contourpy                     1.0.5
# cryptography                  41.0.3
# cycler                        0.11.0
# daal4py                       2023.1.1
# debugpy                       1.6.7
# decorator                     5.1.1
# ...

# %%
pip install flask
# Out:
# ...
#      ---------------------------------------- 0.0/133.1 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/133.1 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/133.1 kB ? eta -:--:--
#      -------- ---------------------------- 30.7/133.1 kB 325.1 kB/s eta 0:00:01
#      -------- ---------------------------- 30.7/133.1 kB 325.1 kB/s eta 0:00:01
#      ----------- ------------------------- 41.0/133.1 kB 195.7 kB/s eta 0:00:01
#      ----------------- ------------------- 61.4/133.1 kB 251.0 kB/s eta 0:00:01
#      ----------------- ------------------- 61.4/133.1 kB 251.0 kB/s eta 0:00:01
#      ------------------- ----------------- 71.7/133.1 kB 206.9 kB/s eta 0:00:01
#      ------------------- ----------------- 71.7/133.1 kB 206.9 kB/s eta 0:00:01
#      ------------------------- ----------- 92.2/133.1 kB 201.3 kB/s eta 0:00:01
#      ------------------------- ----------- 92.2/133.1 kB 201.3 kB/s eta 0:00:01
# ...
